# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ratin = pd.read_csv(r'/Users/ayjeeg/Downloads/FSDS prakash/week 5/Movie_Rating_Advance_Visualization/Movie-Rating.csv')

# %%
ratin
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(ratin)
# Out:
# 559

# %%
ratin.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
ratin.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
ratin.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
ratin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
ratin.isnull().any().any()
# Out:
# False

# %%
ratin.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
ratin.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ratin.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
sb1 = sns.jointplot( data = ratin, x = 'CriticRating', y = 'AudienceRating')
# Audience rating is more dominant then critics rating
# Based on this we find out as most people are most liklihood to watch audience rating & less likely to wathc critics rating
# let me explain the excel - if you filter audience rating & critic rating. critic rating has very low values compare to audience rating

# %%
sb2 = sns.jointplot( data = ratin, x = 'CriticRating', y = 'AudienceRating', kind='reg')

# %%
sb3 = sns.jointplot( data = ratin, x = 'CriticRating', y = 'AudienceRating', kind='hex')

# %%
sb4 = sns.displot(ratin.AudienceRating)
sns.set_style('white') # style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
sb5 = plt.hist(ratin.AudienceRating, bins=30)
# normal distribution aka bell curve aka Guassian distribution

# %%
sb6 = plt.hist(ratin.CriticRating, bins=20) #uniform distribution

# %%
plt.hist(ratin.BudgetMillions)
plt.show()

# %%
plt.hist(ratin[ratin.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(ratin[ratin.Genre == 'Action'].BudgetMillions, bins = 20)
plt.hist(ratin[ratin.Genre == 'Thriller'].BudgetMillions, bins = 20)
plt.hist(ratin[ratin.Genre == 'Drama'].BudgetMillions, bins = 20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([ratin[ratin.Genre == 'Action'].BudgetMillions,
ratin[ratin.Genre == 'Drama'].BudgetMillions,
ratin[ratin.Genre == 'Thriller'].BudgetMillions,
ratin[ratin.Genre == 'Comedy'].BudgetMillions], bins = 20, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things
ratin['Genre'] = ratin['Genre'].astype('category')

for gen in ratin.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sb7 = sns.lmplot(data=ratin, x='CriticRating', y='AudienceRating', fit_reg=False)

# %%
sb8 = sns.lmplot(data=ratin, x='CriticRating', y='AudienceRating', fit_reg=False, hue = 'Genre')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 vis1 = sns.lmplot(data=ratin, x='CriticRating', y='AudienceRating', fit_reg=False, hue = 'Genre',aspect=1, size = 8)
#
# TypeError: lmplot() got an unexpected keyword argument 'size'

# %%
k1 = sns.kdeplot(x = ratin.CriticRating, y = ratin.AudienceRating)

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1 = sns.kdeplot(x = ratin.CriticRating, y = ratin.AudienceRating,
                 shade = True,shade_lowest=False,cmap='Reds')

# %%
k2 = sns.kdeplot(x = ratin.CriticRating, y = ratin.AudienceRating,
                 shade_lowest=False,cmap='Greens_r')

# %%
k2 = sns.kdeplot(x = ratin.BudgetMillions, y = ratin.CriticRating)

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(x = ratin.BudgetMillions, y = ratin.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(x = ratin.BudgetMillions, y = ratin.CriticRating,ax = axes[1])

# %%
#Box plots - 

bp = sns.boxplot(data = ratin, x='Genre', y = 'CriticRating')

# %%
#violin plot

z = sns.violinplot(data = ratin, x='Genre', y = 'CriticRating')

# %%
w1 = sns.boxplot(data = ratin[ratin.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %%
z = sns.violinplot(data=ratin[ratin.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %%
# Creating a Facet grid
g =sns.FacetGrid (ratin, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots

# %%
plt.scatter(x = ratin.CriticRating, y = ratin.AudienceRating)

# %%
g = sns.FacetGrid (ratin, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' ) #scatterplots are mapped in facetgrid

# %%
# you can populated any type of chart. 

g =sns.FacetGrid (ratin, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions') #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (ratin, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws ) #scatterplots are mapped in facetgrid

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(x = ratin.BudgetMillions, y= ratin.AudienceRating, \
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(x = ratin.BudgetMillions, y = ratin.AudienceRating, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x= ratin.BudgetMillions,y = ratin.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x= ratin.BudgetMillions, y = ratin.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=ratin[ratin.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(x = ratin.CriticRating,y = ratin.AudienceRating, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(x = ratin.CriticRating, y= ratin.AudienceRating, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
